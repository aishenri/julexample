# %%
using PyPlot
x = linspace(0,5*pi,100); y = sin(x);
plot(x, y, color="red")
title("A sinusoidally modulated sinusoid");
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fdf6d7d9b70>)
